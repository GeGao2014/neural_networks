# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](https://compsci682-fa18.github.io/assignments2018/assignment1) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs682.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs682.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs682/datasets/cifar-10-batches-py'

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your interests.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs682.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs682.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]


# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
best_svm = None # The LinearSVM object that achieved the highest validation rate.
for lr in learning_rates:
    for rs in regularization_strengths:
        cur_svm = LinearSVM()
        cur_svm.train(X_train_feats, y_train, learning_rate=lr, reg=rs, num_iters=300)
        y_train_pred = cur_svm.predict(X_train_feats)
        training_accuracy = np.mean(y_train == y_train_pred)
        y_pred = cur_svm.predict(X_val_feats)
        accuracy = np.mean(y_val == y_pred)        
        if accuracy > best_val:
            best_val = accuracy
            best_svm = cur_svm
        results[(lr, rs)] = (training_accuracy, accuracy)
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.118020 val accuracy: 0.121000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.093020 val accuracy: 0.085000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.101449 val accuracy: 0.112000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.110184 val accuracy: 0.096000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.092714 val accuracy: 0.099000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.404571 val accuracy: 0.405000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.087571 val accuracy: 0.082000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.395571 val accuracy: 0.384000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.335245 val accuracy: 0.344000
# best validation accuracy achieved during cross-validation: 0.405000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.422

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
# an airplane is misclassified as birds because of the wings

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs682.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

hidden_layer_size = [50,53,56,60,65,70,100]
#num_classes = 10
best_net = None # store the best model into this 
learning_rates = [2e-3,1e-3, 5e-4, 1e-5]
regularization_strengths = [0.1, 0.25, 0.5]

#net = TwoLayerNet(input_dim, hidden_dim, num_classes)
#best_net = None
#learning_rates = [1e-6, 1e-5,1e-4]
#regularization_strengths = [0.1, 0.25, 0.05]
#hidden_layer_size=[55,60,65,70,75,80,90]
# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
for lr in learning_rates:
    for rs in regularization_strengths:
        for hl in hidden_layer_size:

            cur_net = TwoLayerNet(input_dim, hl, num_classes)
            cur_net.train(X_train_feats, y_train, X_val_feats, y_val,
                num_iters=500, batch_size=200,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=rs, verbose=True)
            y_train_pred = cur_net.predict(X_train_feats)
            training_accuracy = np.mean(y_train == y_train_pred)
            y_pred = cur_net.predict(X_val_feats)
            accuracy = np.mean(y_val == y_pred)        
            if accuracy > best_val:
                best_val = accuracy
                best_net = cur_net
            results[(hl,lr, rs)] = (training_accuracy, accuracy)
for hl,lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(hl,lr, reg)]
    print('lr %e hl %e reg %e train accuracy: %f val accuracy: %f ' % (
                lr, hl,reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# Your code
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# iteration 0 / 500: loss 2.302589
# iteration 100 / 500: loss 2.302570
# iteration 200 / 500: loss 2.302591
# iteration 300 / 500: loss 2.302597
# iteration 400 / 500: loss 2.302573
# iteration 0 / 500: loss 2.302589
# iteration 100 / 500: loss 2.302606
# iteration 200 / 500: loss 2.302645
# iteration 300 / 500: loss 2.302589
# iteration 400 / 500: loss 2.302498
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302609
# iteration 200 / 500: loss 2.302604
# iteration 300 / 500: loss 2.302621
# iteration 400 / 500: loss 2.302563
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302624
# iteration 200 / 500: loss 2.302608
# iteration 300 / 500: loss 2.302614
# iteration 400 / 500: loss 2.302586
# iteration 0 / 500: loss 2.302591
# iteration 100 / 500: loss 2.302572
# iteration 200 / 500: loss 2.302599
# iteration 300 / 500: loss 2.302597
# iteration 400 / 500: loss 2.302587
# iteration 0 / 500: loss 2.302591
# iteration 100 / 500: loss 2.302615
# iteration 200 / 500: loss 2.302604
# iteration 300 / 500: loss 2.302627
# iteration 400 / 500: loss 2.302508
# iteration 0 / 500: loss 2.302593
# iteration 100 / 500: loss 2.302569
# iteration 200 / 500: loss 2.302609
# iteration 300 / 500: loss 2.302601
# iteration 400 / 500: loss 2.302511
# iteration 0 / 500: loss 2.302595
# iteration 100 / 500: loss 2.302610
# iteration 200 / 500: loss 2.302556
# iteration 300 / 500: loss 2.302547
# iteration 400 / 500: loss 2.302479
# iteration 0 / 500: loss 2.302596
# iteration 100 / 500: loss 2.302576
# iteration 200 / 500: loss 2.302602
# iteration 300 / 500: loss 2.302601
# iteration 400 / 500: loss 2.302646
# iteration 0 / 500: loss 2.302597
# iteration 100 / 500: loss 2.302662
# iteration 200 / 500: loss 2.302516
# iteration 300 / 500: loss 2.302615
# iteration 400 / 500: loss 2.302588
# iteration 0 / 500: loss 2.302598
# iteration 100 / 500: loss 2.302599
# iteration 200 / 500: loss 2.302610
# iteration 300 / 500: loss 2.302571
# iteration 400 / 500: loss 2.302605
# iteration 0 / 500: loss 2.302598
# iteration 100 / 500: loss 2.302616
# iteration 200 / 500: loss 2.302575
# iteration 300 / 500: loss 2.302654
# iteration 400 / 500: loss 2.302553
# iteration 0 / 500: loss 2.302599
# iteration 100 / 500: loss 2.302585
# iteration 200 / 500: loss 2.302583
# iteration 300 / 500: loss 2.302562
# iteration 400 / 500: loss 2.302638
# iteration 0 / 500: loss 2.302605
# iteration 100 / 500: loss 2.302616
# iteration 200 / 500: loss 2.302547
# iteration 300 / 500: loss 2.302642
# iteration 400 / 500: loss 2.302649
# iteration 0 / 500: loss 2.302605
# iteration 100 / 500: loss 2.302627
# iteration 200 / 500: loss 2.302567
# iteration 300 / 500: loss 2.302594
# iteration 400 / 500: loss 2.302585
# iteration 0 / 500: loss 2.302607
# iteration 100 / 500: loss 2.302584
# iteration 200 / 500: loss 2.302599
# iteration 300 / 500: loss 2.302629
# iteration 400 / 500: loss 2.302685
# iteration 0 / 500: loss 2.302608
# iteration 100 / 500: loss 2.302633
# iteration 200 / 500: loss 2.302579
# iteration 300 / 500: loss 2.302537
# iteration 400 / 500: loss 2.302582
# iteration 0 / 500: loss 2.302609
# iteration 100 / 500: loss 2.302638
# iteration 200 / 500: loss 2.302591
# iteration 300 / 500: loss 2.302564
# iteration 400 / 500: loss 2.302586
# iteration 0 / 500: loss 2.302611
# iteration 100 / 500: loss 2.302638
# iteration 200 / 500: loss 2.302571
# iteration 300 / 500: loss 2.302621
# iteration 400 / 500: loss 2.302657
# iteration 0 / 500: loss 2.302613
# iteration 100 / 500: loss 2.302607
# iteration 200 / 500: loss 2.302634
# iteration 300 / 500: loss 2.302462
# iteration 400 / 500: loss 2.302660
# iteration 0 / 500: loss 2.302626
# iteration 100 / 500: loss 2.302632
# iteration 200 / 500: loss 2.302648
# iteration 300 / 500: loss 2.302650
# iteration 400 / 500: loss 2.302613
# iteration 0 / 500: loss 2.302589
# iteration 100 / 500: loss 2.302593
# iteration 200 / 500: loss 2.302607
# iteration 300 / 500: loss 2.302580
# iteration 400 / 500: loss 2.302568
# iteration 0 / 500: loss 2.302589
# iteration 100 / 500: loss 2.302588
# iteration 200 / 500: loss 2.302597
# iteration 300 / 500: loss 2.302579
# iteration 400 / 500: loss 2.302542
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302584
# iteration 200 / 500: loss 2.302572
# iteration 300 / 500: loss 2.302577
# iteration 400 / 500: loss 2.302571
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302594
# iteration 200 / 500: loss 2.302584
# iteration 300 / 500: loss 2.302565
# iteration 400 / 500: loss 2.302579
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302628
# iteration 200 / 500: loss 2.302623
# iteration 300 / 500: loss 2.302627
# iteration 400 / 500: loss 2.302604
# iteration 0 / 500: loss 2.302591
# iteration 100 / 500: loss 2.302584
# iteration 200 / 500: loss 2.302592
# iteration 300 / 500: loss 2.302589
# iteration 400 / 500: loss 2.302578
# iteration 0 / 500: loss 2.302593
# iteration 100 / 500: loss 2.302605
# iteration 200 / 500: loss 2.302605
# iteration 300 / 500: loss 2.302644
# iteration 400 / 500: loss 2.302590
# iteration 0 / 500: loss 2.302595
# iteration 100 / 500: loss 2.302597
# iteration 200 / 500: loss 2.302581
# iteration 300 / 500: loss 2.302602
# iteration 400 / 500: loss 2.302585
# iteration 0 / 500: loss 2.302596
# iteration 100 / 500: loss 2.302589
# iteration 200 / 500: loss 2.302579
# iteration 300 / 500: loss 2.302586
# iteration 400 / 500: loss 2.302576
# iteration 0 / 500: loss 2.302596
# iteration 100 / 500: loss 2.302593
# iteration 200 / 500: loss 2.302632
# iteration 300 / 500: loss 2.302645
# iteration 400 / 500: loss 2.302629
# iteration 0 / 500: loss 2.302598
# iteration 100 / 500: loss 2.302600
# iteration 200 / 500: loss 2.302593
# iteration 300 / 500: loss 2.302585
# iteration 400 / 500: loss 2.302623
# iteration 0 / 500: loss 2.302598
# iteration 100 / 500: loss 2.302588
# iteration 200 / 500: loss 2.302594
# iteration 300 / 500: loss 2.302620
# iteration 400 / 500: loss 2.302617
# iteration 0 / 500: loss 2.302599
# iteration 100 / 500: loss 2.302607
# iteration 200 / 500: loss 2.302600
# iteration 300 / 500: loss 2.302594
# iteration 400 / 500: loss 2.302625
# iteration 0 / 500: loss 2.302605
# iteration 100 / 500: loss 2.302624
# iteration 200 / 500: loss 2.302621
# iteration 300 / 500: loss 2.302618
# iteration 400 / 500: loss 2.302589
# iteration 0 / 500: loss 2.302605
# iteration 100 / 500: loss 2.302592
# iteration 200 / 500: loss 2.302632
# iteration 300 / 500: loss 2.302582
# iteration 400 / 500: loss 2.302571
# iteration 0 / 500: loss 2.302607
# iteration 100 / 500: loss 2.302617
# iteration 200 / 500: loss 2.302615
# iteration 300 / 500: loss 2.302612
# iteration 400 / 500: loss 2.302583
# iteration 0 / 500: loss 2.302608
# iteration 100 / 500: loss 2.302588
# iteration 200 / 500: loss 2.302597
# iteration 300 / 500: loss 2.302641
# iteration 400 / 500: loss 2.302625
# iteration 0 / 500: loss 2.302610
# iteration 100 / 500: loss 2.302597
# iteration 200 / 500: loss 2.302624
# iteration 300 / 500: loss 2.302608
# iteration 400 / 500: loss 2.302596
# iteration 0 / 500: loss 2.302612
# iteration 100 / 500: loss 2.302621
# iteration 200 / 500: loss 2.302611
# iteration 300 / 500: loss 2.302591
# iteration 400 / 500: loss 2.302630
# iteration 0 / 500: loss 2.302614
# iteration 100 / 500: loss 2.302598
# iteration 200 / 500: loss 2.302590
# iteration 300 / 500: loss 2.302564
# iteration 400 / 500: loss 2.302587
# iteration 0 / 500: loss 2.302626
# iteration 100 / 500: loss 2.302647
# iteration 200 / 500: loss 2.302602
# iteration 300 / 500: loss 2.302671
# iteration 400 / 500: loss 2.302639
# iteration 0 / 500: loss 2.302589
# iteration 100 / 500: loss 2.302593
# iteration 200 / 500: loss 2.302597
# iteration 300 / 500: loss 2.302583
# iteration 400 / 500: loss 2.302569
# iteration 0 / 500: loss 2.302589
# iteration 100 / 500: loss 2.302586
# iteration 200 / 500: loss 2.302586
# iteration 300 / 500: loss 2.302586
# iteration 400 / 500: loss 2.302575
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302588
# iteration 200 / 500: loss 2.302599
# iteration 300 / 500: loss 2.302580
# iteration 400 / 500: loss 2.302593
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302596
# iteration 200 / 500: loss 2.302609
# iteration 300 / 500: loss 2.302592
# iteration 400 / 500: loss 2.302559
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302597
# iteration 200 / 500: loss 2.302594
# iteration 300 / 500: loss 2.302591
# iteration 400 / 500: loss 2.302591
# iteration 0 / 500: loss 2.302591
# iteration 100 / 500: loss 2.302593
# iteration 200 / 500: loss 2.302601
# iteration 300 / 500: loss 2.302606
# iteration 400 / 500: loss 2.302585
# iteration 0 / 500: loss 2.302593
# iteration 100 / 500: loss 2.302591
# iteration 200 / 500: loss 2.302596
# iteration 300 / 500: loss 2.302588
# iteration 400 / 500: loss 2.302583
# iteration 0 / 500: loss 2.302595
# iteration 100 / 500: loss 2.302595
# iteration 200 / 500: loss 2.302594
# iteration 300 / 500: loss 2.302614
# iteration 400 / 500: loss 2.302597
# iteration 0 / 500: loss 2.302596
# iteration 100 / 500: loss 2.302602
# iteration 200 / 500: loss 2.302582
# iteration 300 / 500: loss 2.302580
# iteration 400 / 500: loss 2.302576
# iteration 0 / 500: loss 2.302597
# iteration 100 / 500: loss 2.302606
# iteration 200 / 500: loss 2.302606
# iteration 300 / 500: loss 2.302610
# iteration 400 / 500: loss 2.302618
# iteration 0 / 500: loss 2.302597
# iteration 100 / 500: loss 2.302601
# iteration 200 / 500: loss 2.302606
# iteration 300 / 500: loss 2.302584
# iteration 400 / 500: loss 2.302601
# iteration 0 / 500: loss 2.302598
# iteration 100 / 500: loss 2.302607
# iteration 200 / 500: loss 2.302597
# iteration 300 / 500: loss 2.302579
# iteration 400 / 500: loss 2.302587
# iteration 0 / 500: loss 2.302600
# iteration 100 / 500: loss 2.302597
# iteration 200 / 500: loss 2.302590
# iteration 300 / 500: loss 2.302607
# iteration 400 / 500: loss 2.302589
# iteration 0 / 500: loss 2.302606
# iteration 100 / 500: loss 2.302604
# iteration 200 / 500: loss 2.302595
# iteration 300 / 500: loss 2.302602
# iteration 400 / 500: loss 2.302590
# iteration 0 / 500: loss 2.302605
# iteration 100 / 500: loss 2.302606
# iteration 200 / 500: loss 2.302595
# iteration 300 / 500: loss 2.302608
# iteration 400 / 500: loss 2.302600
# iteration 0 / 500: loss 2.302607
# iteration 100 / 500: loss 2.302603
# iteration 200 / 500: loss 2.302605
# iteration 300 / 500: loss 2.302606
# iteration 400 / 500: loss 2.302598
# iteration 0 / 500: loss 2.302608
# iteration 100 / 500: loss 2.302594
# iteration 200 / 500: loss 2.302608
# iteration 300 / 500: loss 2.302619
# iteration 400 / 500: loss 2.302588
# iteration 0 / 500: loss 2.302609
# iteration 100 / 500: loss 2.302615
# iteration 200 / 500: loss 2.302605
# iteration 300 / 500: loss 2.302597
# iteration 400 / 500: loss 2.302594
# iteration 0 / 500: loss 2.302612
# iteration 100 / 500: loss 2.302611
# iteration 200 / 500: loss 2.302602
# iteration 300 / 500: loss 2.302610
# iteration 400 / 500: loss 2.302608
# iteration 0 / 500: loss 2.302614
# iteration 100 / 500: loss 2.302624
# iteration 200 / 500: loss 2.302625
# iteration 300 / 500: loss 2.302610
# iteration 400 / 500: loss 2.302621
# iteration 0 / 500: loss 2.302626
# iteration 100 / 500: loss 2.302626
# iteration 200 / 500: loss 2.302622
# iteration 300 / 500: loss 2.302628
# iteration 400 / 500: loss 2.302627
# iteration 0 / 500: loss 2.302589
# iteration 100 / 500: loss 2.302589
# iteration 200 / 500: loss 2.302589
# iteration 300 / 500: loss 2.302589
# iteration 400 / 500: loss 2.302589
# iteration 0 / 500: loss 2.302589
# iteration 100 / 500: loss 2.302590
# iteration 200 / 500: loss 2.302590
# iteration 300 / 500: loss 2.302589
# iteration 400 / 500: loss 2.302590
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302590
# iteration 200 / 500: loss 2.302590
# iteration 300 / 500: loss 2.302590
# iteration 400 / 500: loss 2.302590
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302590
# iteration 200 / 500: loss 2.302590
# iteration 300 / 500: loss 2.302590
# iteration 400 / 500: loss 2.302590
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss 2.302590
# iteration 200 / 500: loss 2.302590
# iteration 300 / 500: loss 2.302591
# iteration 400 / 500: loss 2.302590
# iteration 0 / 500: loss 2.302591
# iteration 100 / 500: loss 2.302591
# iteration 200 / 500: loss 2.302591
# iteration 300 / 500: loss 2.302591
# iteration 400 / 500: loss 2.302591
# iteration 0 / 500: loss 2.302593
# iteration 100 / 500: loss 2.302593
# iteration 200 / 500: loss 2.302593
# iteration 300 / 500: loss 2.302594
# iteration 400 / 500: loss 2.302593
# iteration 0 / 500: loss 2.302596
# iteration 100 / 500: loss 2.302596
# iteration 200 / 500: loss 2.302596
# iteration 300 / 500: loss 2.302595
# iteration 400 / 500: loss 2.302596
# iteration 0 / 500: loss 2.302596
# iteration 100 / 500: loss 2.302596
# iteration 200 / 500: loss 2.302596
# iteration 300 / 500: loss 2.302596
# iteration 400 / 500: loss 2.302596
# iteration 0 / 500: loss 2.302597
# iteration 100 / 500: loss 2.302597
# iteration 200 / 500: loss 2.302597
# iteration 300 / 500: loss 2.302597
# iteration 400 / 500: loss 2.302597
# iteration 0 / 500: loss 2.302597
# iteration 100 / 500: loss 2.302597
# iteration 200 / 500: loss 2.302597
# iteration 300 / 500: loss 2.302597
# iteration 400 / 500: loss 2.302597
# iteration 0 / 500: loss 2.302598
# iteration 100 / 500: loss 2.302598
# iteration 200 / 500: loss 2.302598
# iteration 300 / 500: loss 2.302598
# iteration 400 / 500: loss 2.302598
# iteration 0 / 500: loss 2.302599
# iteration 100 / 500: loss 2.302599
# iteration 200 / 500: loss 2.302600
# iteration 300 / 500: loss 2.302599
# iteration 400 / 500: loss 2.302599
# iteration 0 / 500: loss 2.302606
# iteration 100 / 500: loss 2.302606
# iteration 200 / 500: loss 2.302606
# iteration 300 / 500: loss 2.302606
# iteration 400 / 500: loss 2.302606
# iteration 0 / 500: loss 2.302606
# iteration 100 / 500: loss 2.302606
# iteration 200 / 500: loss 2.302606
# iteration 300 / 500: loss 2.302606
# iteration 400 / 500: loss 2.302606
# iteration 0 / 500: loss 2.302607
# iteration 100 / 500: loss 2.302607
# iteration 200 / 500: loss 2.302606
# iteration 300 / 500: loss 2.302607
# iteration 400 / 500: loss 2.302607
# iteration 0 / 500: loss 2.302608
# iteration 100 / 500: loss 2.302608
# iteration 200 / 500: loss 2.302607
# iteration 300 / 500: loss 2.302607
# iteration 400 / 500: loss 2.302608
# iteration 0 / 500: loss 2.302609
# iteration 100 / 500: loss 2.302609
# iteration 200 / 500: loss 2.302609
# iteration 300 / 500: loss 2.302609
# iteration 400 / 500: loss 2.302609
# iteration 0 / 500: loss 2.302612
# iteration 100 / 500: loss 2.302612
# iteration 200 / 500: loss 2.302612
# iteration 300 / 500: loss 2.302611
# iteration 400 / 500: loss 2.302612
# iteration 0 / 500: loss 2.302614
# iteration 100 / 500: loss 2.302614
# iteration 200 / 500: loss 2.302614
# iteration 300 / 500: loss 2.302614
# iteration 400 / 500: loss 2.302614
# iteration 0 / 500: loss 2.302626
# iteration 100 / 500: loss 2.302626
# iteration 200 / 500: loss 2.302626
# iteration 300 / 500: loss 2.302626
# iteration 400 / 500: loss 2.302626
# lr 1.000000e-05 hl 5.000000e+01 reg 1.000000e-01 train accuracy: 0.099612 val accuracy: 0.119000
# lr 1.000000e-05 hl 5.000000e+01 reg 2.500000e-01 train accuracy: 0.099673 val accuracy: 0.113000
# lr 1.000000e-05 hl 5.000000e+01 reg 5.000000e-01 train accuracy: 0.092796 val accuracy: 0.100000
# lr 5.000000e-04 hl 5.000000e+01 reg 1.000000e-01 train accuracy: 0.099755 val accuracy: 0.112000
# lr 5.000000e-04 hl 5.000000e+01 reg 2.500000e-01 train accuracy: 0.100449 val accuracy: 0.078000
# lr 5.000000e-04 hl 5.000000e+01 reg 5.000000e-01 train accuracy: 0.100449 val accuracy: 0.078000
# lr 1.000000e-03 hl 5.000000e+01 reg 1.000000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 1.000000e-03 hl 5.000000e+01 reg 2.500000e-01 train accuracy: 0.099857 val accuracy: 0.107000
# lr 1.000000e-03 hl 5.000000e+01 reg 5.000000e-01 train accuracy: 0.100449 val accuracy: 0.078000
# lr 2.000000e-03 hl 5.000000e+01 reg 1.000000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 2.000000e-03 hl 5.000000e+01 reg 2.500000e-01 train accuracy: 0.100449 val accuracy: 0.078000
# lr 2.000000e-03 hl 5.000000e+01 reg 5.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 hl 5.300000e+01 reg 1.000000e-01 train accuracy: 0.104714 val accuracy: 0.121000
# lr 1.000000e-05 hl 5.300000e+01 reg 2.500000e-01 train accuracy: 0.100041 val accuracy: 0.098000
# lr 1.000000e-05 hl 5.300000e+01 reg 5.000000e-01 train accuracy: 0.099980 val accuracy: 0.105000
# lr 5.000000e-04 hl 5.300000e+01 reg 1.000000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 5.000000e-04 hl 5.300000e+01 reg 2.500000e-01 train accuracy: 0.100041 val accuracy: 0.098000
# lr 5.000000e-04 hl 5.300000e+01 reg 5.000000e-01 train accuracy: 0.099735 val accuracy: 0.113000
# lr 1.000000e-03 hl 5.300000e+01 reg 1.000000e-01 train accuracy: 0.099959 val accuracy: 0.102000
# lr 1.000000e-03 hl 5.300000e+01 reg 2.500000e-01 train accuracy: 0.099755 val accuracy: 0.112000
# lr 1.000000e-03 hl 5.300000e+01 reg 5.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.000000e-03 hl 5.300000e+01 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.000000e-03 hl 5.300000e+01 reg 2.500000e-01 train accuracy: 0.100449 val accuracy: 0.078000
# lr 2.000000e-03 hl 5.300000e+01 reg 5.000000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 1.000000e-05 hl 5.600000e+01 reg 1.000000e-01 train accuracy: 0.099959 val accuracy: 0.098000
# lr 1.000000e-05 hl 5.600000e+01 reg 2.500000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-05 hl 5.600000e+01 reg 5.000000e-01 train accuracy: 0.100388 val accuracy: 0.079000
# lr 5.000000e-04 hl 5.600000e+01 reg 1.000000e-01 train accuracy: 0.099898 val accuracy: 0.105000
# lr 5.000000e-04 hl 5.600000e+01 reg 2.500000e-01 train accuracy: 0.099898 val accuracy: 0.105000
# lr 5.000000e-04 hl 5.600000e+01 reg 5.000000e-01 train accuracy: 0.100449 val accuracy: 0.078000
# lr 1.000000e-03 hl 5.600000e+01 reg 1.000000e-01 train accuracy: 0.099857 val accuracy: 0.107000
# lr 1.000000e-03 hl 5.600000e+01 reg 2.500000e-01 train accuracy: 0.100449 val accuracy: 0.078000
# lr 1.000000e-03 hl 5.600000e+01 reg 5.000000e-01 train accuracy: 0.099857 val accuracy: 0.107000
# lr 2.000000e-03 hl 5.600000e+01 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.000000e-03 hl 5.600000e+01 reg 2.500000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 2.000000e-03 hl 5.600000e+01 reg 5.000000e-01 train accuracy: 0.099898 val accuracy: 0.105000
# lr 1.000000e-05 hl 6.000000e+01 reg 1.000000e-01 train accuracy: 0.100408 val accuracy: 0.079000
# lr 1.000000e-05 hl 6.000000e+01 reg 2.500000e-01 train accuracy: 0.099918 val accuracy: 0.105000
# lr 1.000000e-05 hl 6.000000e+01 reg 5.000000e-01 train accuracy: 0.090429 val accuracy: 0.077000
# lr 5.000000e-04 hl 6.000000e+01 reg 1.000000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 5.000000e-04 hl 6.000000e+01 reg 2.500000e-01 train accuracy: 0.099735 val accuracy: 0.113000
# lr 5.000000e-04 hl 6.000000e+01 reg 5.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-03 hl 6.000000e+01 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-03 hl 6.000000e+01 reg 2.500000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 1.000000e-03 hl 6.000000e+01 reg 5.000000e-01 train accuracy: 0.100041 val accuracy: 0.098000
# lr 2.000000e-03 hl 6.000000e+01 reg 1.000000e-01 train accuracy: 0.099755 val accuracy: 0.112000
# lr 2.000000e-03 hl 6.000000e+01 reg 2.500000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 2.000000e-03 hl 6.000000e+01 reg 5.000000e-01 train accuracy: 0.099755 val accuracy: 0.112000
# lr 1.000000e-05 hl 6.500000e+01 reg 1.000000e-01 train accuracy: 0.099980 val accuracy: 0.102000
# lr 1.000000e-05 hl 6.500000e+01 reg 2.500000e-01 train accuracy: 0.098408 val accuracy: 0.109000
# lr 1.000000e-05 hl 6.500000e+01 reg 5.000000e-01 train accuracy: 0.119633 val accuracy: 0.108000
# lr 5.000000e-04 hl 6.500000e+01 reg 1.000000e-01 train accuracy: 0.099898 val accuracy: 0.105000
# lr 5.000000e-04 hl 6.500000e+01 reg 2.500000e-01 train accuracy: 0.099898 val accuracy: 0.105000
# lr 5.000000e-04 hl 6.500000e+01 reg 5.000000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 1.000000e-03 hl 6.500000e+01 reg 1.000000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 1.000000e-03 hl 6.500000e+01 reg 2.500000e-01 train accuracy: 0.100041 val accuracy: 0.098000
# lr 1.000000e-03 hl 6.500000e+01 reg 5.000000e-01 train accuracy: 0.099959 val accuracy: 0.102000
# lr 2.000000e-03 hl 6.500000e+01 reg 1.000000e-01 train accuracy: 0.099612 val accuracy: 0.119000
# lr 2.000000e-03 hl 6.500000e+01 reg 2.500000e-01 train accuracy: 0.100041 val accuracy: 0.098000
# lr 2.000000e-03 hl 6.500000e+01 reg 5.000000e-01 train accuracy: 0.099898 val accuracy: 0.105000
# lr 1.000000e-05 hl 7.000000e+01 reg 1.000000e-01 train accuracy: 0.091000 val accuracy: 0.108000
# lr 1.000000e-05 hl 7.000000e+01 reg 2.500000e-01 train accuracy: 0.099694 val accuracy: 0.113000
# lr 1.000000e-05 hl 7.000000e+01 reg 5.000000e-01 train accuracy: 0.100490 val accuracy: 0.078000
# lr 5.000000e-04 hl 7.000000e+01 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-04 hl 7.000000e+01 reg 2.500000e-01 train accuracy: 0.099755 val accuracy: 0.112000
# lr 5.000000e-04 hl 7.000000e+01 reg 5.000000e-01 train accuracy: 0.099857 val accuracy: 0.107000
# lr 1.000000e-03 hl 7.000000e+01 reg 1.000000e-01 train accuracy: 0.099755 val accuracy: 0.112000
# lr 1.000000e-03 hl 7.000000e+01 reg 2.500000e-01 train accuracy: 0.100449 val accuracy: 0.078000
# lr 1.000000e-03 hl 7.000000e+01 reg 5.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.000000e-03 hl 7.000000e+01 reg 1.000000e-01 train accuracy: 0.099612 val accuracy: 0.119000
# lr 2.000000e-03 hl 7.000000e+01 reg 2.500000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 2.000000e-03 hl 7.000000e+01 reg 5.000000e-01 train accuracy: 0.099959 val accuracy: 0.102000
# lr 1.000000e-05 hl 1.000000e+02 reg 1.000000e-01 train accuracy: 0.098510 val accuracy: 0.085000
# lr 1.000000e-05 hl 1.000000e+02 reg 2.500000e-01 train accuracy: 0.099796 val accuracy: 0.119000
# lr 1.000000e-05 hl 1.000000e+02 reg 5.000000e-01 train accuracy: 0.093286 val accuracy: 0.079000
# lr 5.000000e-04 hl 1.000000e+02 reg 1.000000e-01 train accuracy: 0.100449 val accuracy: 0.078000
# lr 5.000000e-04 hl 1.000000e+02 reg 2.500000e-01 train accuracy: 0.099898 val accuracy: 0.105000
# lr 5.000000e-04 hl 1.000000e+02 reg 5.000000e-01 train accuracy: 0.100449 val accuracy: 0.078000
# lr 1.000000e-03 hl 1.000000e+02 reg 1.000000e-01 train accuracy: 0.099755 val accuracy: 0.112000
# lr 1.000000e-03 hl 1.000000e+02 reg 2.500000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-03 hl 1.000000e+02 reg 5.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.000000e-03 hl 1.000000e+02 reg 1.000000e-01 train accuracy: 0.099857 val accuracy: 0.107000
# lr 2.000000e-03 hl 1.000000e+02 reg 2.500000e-01 train accuracy: 0.100429 val accuracy: 0.079000
# lr 2.000000e-03 hl 1.000000e+02 reg 5.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.121000

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.094
