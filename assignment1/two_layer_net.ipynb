# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs682.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs682/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs682/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# (3.3864457783041217, {'W1': array([[ 0.9011439 ,  0.        ,  0.55226823,  0.29990116,  0.62670847,
#          0.        ,  0.        , -0.06772897,  0.22222636,  0.19645425],
#        [-0.3393863 ,  0.        , -0.79420546, -0.41228145, -0.88170532,
#          0.        ,  0.        , -0.34481856, -0.76574544, -0.35805   ],
#        [-0.29301574,  0.        ,  0.91851343,  0.40563854,  0.91443281,
#          0.        ,  0.        ,  0.01658136,  1.14378255,  0.31149933],
#        [-0.59525465,  0.        , -1.2212134 , -0.53633724, -1.20030154,
#          0.        ,  0.        ,  0.22892701, -1.03803548, -0.34454545]]), 'b1': array([[ 0.05547736,  0.        ,  0.09617915,  0.04377641,  0.09687975,
#          0.        ,  0.        ,  0.03927952,  0.07924568,  0.03666036]]), 'W2': array([[-0.50327916, -0.6104617 , -0.47004876],
#        [ 0.        ,  0.        ,  0.        ],
#        [-0.86395326, -1.12573193, -0.9958293 ],
#        [-1.45504824, -1.87096532, -1.55524441],
#        [-1.52145989, -2.0705181 , -1.79210809],
#        [ 0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ],
#        [-0.11448865, -0.12176903, -0.12336701],
#        [-0.80258014, -1.08136772, -0.98177179],
#        [-1.31307995, -1.80502032, -1.57256993]]), 'b2': array([[-0.5900309, -0.7431905, -0.6667786]])})
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-2019583e1a80> in <module>()
#      15 # The difference should be very small. We get < 1e-7
#      16 print('Difference between your scores and correct scores:')
# ---> 17 print(np.sum(np.abs(scores - correct_scores)))
#
# ValueError: operands could not be broadcast together with shapes (2,) (5,3)

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 0.0189654196061

# %%
print(net.params['b1'].shape)
# Out:
# (10,)

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs682.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09
# W2 max relative error: 3.440708e-09
# b2 max relative error: 4.447677e-11

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171436435329

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs682.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs682/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302777
# iteration 100 / 1000: loss 2.302370
# iteration 200 / 1000: loss 2.299480
# iteration 300 / 1000: loss 2.269344
# iteration 400 / 1000: loss 2.173975
# iteration 500 / 1000: loss 2.131253
# iteration 600 / 1000: loss 2.067382
# iteration 700 / 1000: loss 2.039747
# iteration 800 / 1000: loss 1.932234
# iteration 900 / 1000: loss 2.015783
# Validation accuracy:  0.288

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
from cs682.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
input_size = 32 * 32 * 3
hidden_size = [50,53,56,60,65,70,100]
num_classes = 10
best_net = None # store the best model into this 
learning_rates = [2e-3,1e-3, 5e-4, 1e-5]
regularization_strengths = [0.1, 0.25, 0.5]

# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
for lr in learning_rates:
    for rs in regularization_strengths:
        for hl in hidden_size:

            cur_net = TwoLayerNet(input_size, hl, num_classes)
            cur_net.train(X_train, y_train, X_val, y_val,
                num_iters=500, batch_size=200,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=rs, verbose=True)
            y_train_pred = cur_net.predict(X_train)
            training_accuracy = np.mean(y_train == y_train_pred)
            y_pred = cur_net.predict(X_val)
            accuracy = np.mean(y_val == y_pred)        
            if accuracy > best_val:
                best_val = accuracy
                best_net = cur_net
            results[(hl,lr, rs)] = (training_accuracy, accuracy)
#############################################################
#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# Your code
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# iteration 0 / 500: loss 2.302678
# iteration 100 / 500: loss 1.846244
# iteration 200 / 500: loss 1.655898
# iteration 300 / 500: loss 1.754391
# iteration 400 / 500: loss 1.617558
# iteration 0 / 500: loss 2.302652
# iteration 100 / 500: loss 1.726676
# iteration 200 / 500: loss 1.663757
# iteration 300 / 500: loss 1.542730
# iteration 400 / 500: loss 1.576891
# iteration 0 / 500: loss 2.302679
# iteration 100 / 500: loss 1.806508
# iteration 200 / 500: loss 1.639846
# iteration 300 / 500: loss 1.591254
# iteration 400 / 500: loss 1.656009
# iteration 0 / 500: loss 2.302682
# iteration 100 / 500: loss 1.830122
# iteration 200 / 500: loss 1.659771
# iteration 300 / 500: loss 1.610679
# iteration 400 / 500: loss 1.631631
# iteration 0 / 500: loss 2.302663
# iteration 100 / 500: loss 1.825738
# iteration 200 / 500: loss 1.677925
# iteration 300 / 500: loss 1.707118
# iteration 400 / 500: loss 1.560877
# iteration 0 / 500: loss 2.302704
# iteration 100 / 500: loss 1.787571
# iteration 200 / 500: loss 1.723996
# iteration 300 / 500: loss 1.619763
# iteration 400 / 500: loss 1.531157
# iteration 0 / 500: loss 2.302776
# iteration 100 / 500: loss 1.811613
# iteration 200 / 500: loss 1.694151
# iteration 300 / 500: loss 1.575930
# iteration 400 / 500: loss 1.589694
# iteration 0 / 500: loss 2.302764
# iteration 100 / 500: loss 1.820788
# iteration 200 / 500: loss 1.676720
# iteration 300 / 500: loss 1.573140
# iteration 400 / 500: loss 1.599996
# iteration 0 / 500: loss 2.302791
# iteration 100 / 500: loss 1.786814
# iteration 200 / 500: loss 1.804989
# iteration 300 / 500: loss 1.663595
# iteration 400 / 500: loss 1.728419
# iteration 0 / 500: loss 2.302797
# iteration 100 / 500: loss 1.779755
# iteration 200 / 500: loss 1.738031
# iteration 300 / 500: loss 1.672902
# iteration 400 / 500: loss 1.625702
# iteration 0 / 500: loss 2.302805
# iteration 100 / 500: loss 1.827667
# iteration 200 / 500: loss 1.678294
# iteration 300 / 500: loss 1.745610
# iteration 400 / 500: loss 1.865915
# iteration 0 / 500: loss 2.302834
# iteration 100 / 500: loss 1.819203
# iteration 200 / 500: loss 1.720973
# iteration 300 / 500: loss 1.671223
# iteration 400 / 500: loss 1.423091
# iteration 0 / 500: loss 2.302839
# iteration 100 / 500: loss 1.744717
# iteration 200 / 500: loss 1.630356
# iteration 300 / 500: loss 1.660260
# iteration 400 / 500: loss 1.662077
# iteration 0 / 500: loss 2.303013
# iteration 100 / 500: loss 1.722608
# iteration 200 / 500: loss 1.782637
# iteration 300 / 500: loss 1.824769
# iteration 400 / 500: loss 1.513069
# iteration 0 / 500: loss 2.302968
# iteration 100 / 500: loss 1.850479
# iteration 200 / 500: loss 1.847344
# iteration 300 / 500: loss 1.704182
# iteration 400 / 500: loss 1.572164
# iteration 0 / 500: loss 2.303005
# iteration 100 / 500: loss 1.800817
# iteration 200 / 500: loss 1.593077
# iteration 300 / 500: loss 1.492943
# iteration 400 / 500: loss 1.641947
# iteration 0 / 500: loss 2.303017
# iteration 100 / 500: loss 1.879559
# iteration 200 / 500: loss 1.658544
# iteration 300 / 500: loss 1.699512
# iteration 400 / 500: loss 1.504295
# iteration 0 / 500: loss 2.303036
# iteration 100 / 500: loss 1.827336
# iteration 200 / 500: loss 1.765739
# iteration 300 / 500: loss 1.723017
# iteration 400 / 500: loss 1.586338
# iteration 0 / 500: loss 2.303058
# iteration 100 / 500: loss 1.794742
# iteration 200 / 500: loss 1.728639
# iteration 300 / 500: loss 1.616877
# iteration 400 / 500: loss 1.567700
# iteration 0 / 500: loss 2.303135
# iteration 100 / 500: loss 1.851211
# iteration 200 / 500: loss 1.744404
# iteration 300 / 500: loss 1.716436
# iteration 400 / 500: loss 1.626839
# iteration 0 / 500: loss 2.303352
# iteration 100 / 500: loss 1.744667
# iteration 200 / 500: loss 1.706794
# iteration 300 / 500: loss 1.632365
# iteration 400 / 500: loss 1.577851
# iteration 0 / 500: loss 2.302678
# iteration 100 / 500: loss 1.903253
# iteration 200 / 500: loss 1.732376
# iteration 300 / 500: loss 1.660804
# iteration 400 / 500: loss 1.612236
# iteration 0 / 500: loss 2.302663
# iteration 100 / 500: loss 1.976662
# iteration 200 / 500: loss 1.732948
# iteration 300 / 500: loss 1.706073
# iteration 400 / 500: loss 1.653807
# iteration 0 / 500: loss 2.302703
# iteration 100 / 500: loss 1.931746
# iteration 200 / 500: loss 1.738663
# iteration 300 / 500: loss 1.616614
# iteration 400 / 500: loss 1.599259
# iteration 0 / 500: loss 2.302660
# iteration 100 / 500: loss 1.922158
# iteration 200 / 500: loss 1.835051
# iteration 300 / 500: loss 1.764061
# iteration 400 / 500: loss 1.629469
# iteration 0 / 500: loss 2.302664
# iteration 100 / 500: loss 1.824763
# iteration 200 / 500: loss 1.811742
# iteration 300 / 500: loss 1.658094
# iteration 400 / 500: loss 1.531997
# iteration 0 / 500: loss 2.302693
# iteration 100 / 500: loss 1.889093
# iteration 200 / 500: loss 1.833022
# iteration 300 / 500: loss 1.721128
# iteration 400 / 500: loss 1.558802
# iteration 0 / 500: loss 2.302707
# iteration 100 / 500: loss 1.894987
# iteration 200 / 500: loss 1.825009
# iteration 300 / 500: loss 1.716889
# iteration 400 / 500: loss 1.699229
# iteration 0 / 500: loss 2.302791
# iteration 100 / 500: loss 1.985554
# iteration 200 / 500: loss 1.778234
# iteration 300 / 500: loss 1.664407
# iteration 400 / 500: loss 1.627253
# iteration 0 / 500: loss 2.302767
# iteration 100 / 500: loss 1.895732
# iteration 200 / 500: loss 1.833641
# iteration 300 / 500: loss 1.751078
# iteration 400 / 500: loss 1.714107
# iteration 0 / 500: loss 2.302816
# iteration 100 / 500: loss 1.959042
# iteration 200 / 500: loss 1.722436
# iteration 300 / 500: loss 1.574121
# iteration 400 / 500: loss 1.588431
# iteration 0 / 500: loss 2.302803
# iteration 100 / 500: loss 2.065647
# iteration 200 / 500: loss 1.740604
# iteration 300 / 500: loss 1.586150
# iteration 400 / 500: loss 1.556266
# iteration 0 / 500: loss 2.302833
# iteration 100 / 500: loss 1.942559
# iteration 200 / 500: loss 1.733077
# iteration 300 / 500: loss 1.670108
# iteration 400 / 500: loss 1.668987
# iteration 0 / 500: loss 2.302848
# iteration 100 / 500: loss 1.918799
# iteration 200 / 500: loss 1.723182
# iteration 300 / 500: loss 1.686024
# iteration 400 / 500: loss 1.619770
# iteration 0 / 500: loss 2.302957
# iteration 100 / 500: loss 1.931935
# iteration 200 / 500: loss 1.553168
# iteration 300 / 500: loss 1.597824
# iteration 400 / 500: loss 1.487729
# iteration 0 / 500: loss 2.302943
# iteration 100 / 500: loss 2.015542
# iteration 200 / 500: loss 1.792214
# iteration 300 / 500: loss 1.674208
# iteration 400 / 500: loss 1.751489
# iteration 0 / 500: loss 2.302993
# iteration 100 / 500: loss 1.992726
# iteration 200 / 500: loss 1.695408
# iteration 300 / 500: loss 1.720251
# iteration 400 / 500: loss 1.617888
# iteration 0 / 500: loss 2.303025
# iteration 100 / 500: loss 1.924987
# iteration 200 / 500: loss 1.879337
# iteration 300 / 500: loss 1.786854
# iteration 400 / 500: loss 1.748745
# iteration 0 / 500: loss 2.303031
# iteration 100 / 500: loss 1.907360
# iteration 200 / 500: loss 1.657142
# iteration 300 / 500: loss 1.749444
# iteration 400 / 500: loss 1.591524
# iteration 0 / 500: loss 2.303106
# iteration 100 / 500: loss 1.934233
# iteration 200 / 500: loss 1.799070
# iteration 300 / 500: loss 1.705566
# iteration 400 / 500: loss 1.600170
# iteration 0 / 500: loss 2.303101
# iteration 100 / 500: loss 1.878960
# iteration 200 / 500: loss 1.784029
# iteration 300 / 500: loss 1.591350
# iteration 400 / 500: loss 1.791187
# iteration 0 / 500: loss 2.303333
# iteration 100 / 500: loss 1.896591
# iteration 200 / 500: loss 1.714926
# iteration 300 / 500: loss 1.714140
# iteration 400 / 500: loss 1.503350
# iteration 0 / 500: loss 2.302658
# iteration 100 / 500: loss 2.141059
# iteration 200 / 500: loss 1.889724
# iteration 300 / 500: loss 1.792371
# iteration 400 / 500: loss 1.718782
# iteration 0 / 500: loss 2.302714
# iteration 100 / 500: loss 2.113720
# iteration 200 / 500: loss 1.888921
# iteration 300 / 500: loss 1.804055
# iteration 400 / 500: loss 1.822565
# iteration 0 / 500: loss 2.302697
# iteration 100 / 500: loss 2.143537
# iteration 200 / 500: loss 1.921650
# iteration 300 / 500: loss 1.832090
# iteration 400 / 500: loss 1.714777
# iteration 0 / 500: loss 2.302673
# iteration 100 / 500: loss 2.146108
# iteration 200 / 500: loss 1.938039
# iteration 300 / 500: loss 1.747054
# iteration 400 / 500: loss 1.705827
# iteration 0 / 500: loss 2.302681
# iteration 100 / 500: loss 2.130381
# iteration 200 / 500: loss 1.944214
# iteration 300 / 500: loss 1.947458
# iteration 400 / 500: loss 1.781974
# iteration 0 / 500: loss 2.302713
# iteration 100 / 500: loss 2.149929
# iteration 200 / 500: loss 1.892166
# iteration 300 / 500: loss 1.758691
# iteration 400 / 500: loss 1.699278
# iteration 0 / 500: loss 2.302714
# iteration 100 / 500: loss 2.104416
# iteration 200 / 500: loss 2.017753
# iteration 300 / 500: loss 1.870802
# iteration 400 / 500: loss 1.755674
# iteration 0 / 500: loss 2.302769
# iteration 100 / 500: loss 2.098972
# iteration 200 / 500: loss 1.888282
# iteration 300 / 500: loss 1.738905
# iteration 400 / 500: loss 1.804826
# iteration 0 / 500: loss 2.302795
# iteration 100 / 500: loss 2.105732
# iteration 200 / 500: loss 1.929140
# iteration 300 / 500: loss 1.779416
# iteration 400 / 500: loss 1.811809
# iteration 0 / 500: loss 2.302807
# iteration 100 / 500: loss 2.104336
# iteration 200 / 500: loss 1.926599
# iteration 300 / 500: loss 1.785394
# iteration 400 / 500: loss 1.694223
# iteration 0 / 500: loss 2.302804
# iteration 100 / 500: loss 2.146106
# iteration 200 / 500: loss 1.952313
# iteration 300 / 500: loss 1.931401
# iteration 400 / 500: loss 1.663879
# iteration 0 / 500: loss 2.302835
# iteration 100 / 500: loss 2.097807
# iteration 200 / 500: loss 1.999889
# iteration 300 / 500: loss 1.927795
# iteration 400 / 500: loss 1.759720
# iteration 0 / 500: loss 2.302860
# iteration 100 / 500: loss 2.156241
# iteration 200 / 500: loss 1.962705
# iteration 300 / 500: loss 1.782973
# iteration 400 / 500: loss 1.839624
# iteration 0 / 500: loss 2.302938
# iteration 100 / 500: loss 2.135257
# iteration 200 / 500: loss 1.849563
# iteration 300 / 500: loss 1.864176
# iteration 400 / 500: loss 1.721061
# iteration 0 / 500: loss 2.302952
# iteration 100 / 500: loss 2.117857
# iteration 200 / 500: loss 1.926083
# iteration 300 / 500: loss 1.821841
# iteration 400 / 500: loss 1.767719
# iteration 0 / 500: loss 2.302989
# iteration 100 / 500: loss 2.122768
# iteration 200 / 500: loss 1.938759
# iteration 300 / 500: loss 1.851851
# iteration 400 / 500: loss 1.660797
# iteration 0 / 500: loss 2.303008
# iteration 100 / 500: loss 2.117398
# iteration 200 / 500: loss 1.867807
# iteration 300 / 500: loss 1.824801
# iteration 400 / 500: loss 1.716876
# iteration 0 / 500: loss 2.303065
# iteration 100 / 500: loss 2.098089
# iteration 200 / 500: loss 1.935261
# iteration 300 / 500: loss 1.842099
# iteration 400 / 500: loss 1.750590
# iteration 0 / 500: loss 2.303093
# iteration 100 / 500: loss 2.169524
# iteration 200 / 500: loss 2.022465
# iteration 300 / 500: loss 1.747837
# iteration 400 / 500: loss 1.686035
# iteration 0 / 500: loss 2.303136
# iteration 100 / 500: loss 2.130407
# iteration 200 / 500: loss 1.928841
# iteration 300 / 500: loss 1.885297
# iteration 400 / 500: loss 1.753653
# iteration 0 / 500: loss 2.303379
# iteration 100 / 500: loss 2.102003
# iteration 200 / 500: loss 1.938453
# iteration 300 / 500: loss 1.805597
# iteration 400 / 500: loss 1.736975
# iteration 0 / 500: loss 2.302639
# iteration 100 / 500: loss 2.302626
# iteration 200 / 500: loss 2.302627
# iteration 300 / 500: loss 2.302603
# iteration 400 / 500: loss 2.302588
# iteration 0 / 500: loss 2.302632
# iteration 100 / 500: loss 2.302640
# iteration 200 / 500: loss 2.302598
# iteration 300 / 500: loss 2.302531
# iteration 400 / 500: loss 2.302540
# iteration 0 / 500: loss 2.302694
# iteration 100 / 500: loss 2.302660
# iteration 200 / 500: loss 2.302631
# iteration 300 / 500: loss 2.302619
# iteration 400 / 500: loss 2.302600
# iteration 0 / 500: loss 2.302659
# iteration 100 / 500: loss 2.302632
# iteration 200 / 500: loss 2.302603
# iteration 300 / 500: loss 2.302552
# iteration 400 / 500: loss 2.302546
# iteration 0 / 500: loss 2.302674
# iteration 100 / 500: loss 2.302625
# iteration 200 / 500: loss 2.302611
# iteration 300 / 500: loss 2.302483
# iteration 400 / 500: loss 2.302519
# iteration 0 / 500: loss 2.302679
# iteration 100 / 500: loss 2.302669
# iteration 200 / 500: loss 2.302621
# iteration 300 / 500: loss 2.302587
# iteration 400 / 500: loss 2.302565
# iteration 0 / 500: loss 2.302746
# iteration 100 / 500: loss 2.302705
# iteration 200 / 500: loss 2.302640
# iteration 300 / 500: loss 2.302576
# iteration 400 / 500: loss 2.302506
# iteration 0 / 500: loss 2.302761
# iteration 100 / 500: loss 2.302769
# iteration 200 / 500: loss 2.302731
# iteration 300 / 500: loss 2.302722
# iteration 400 / 500: loss 2.302659
# iteration 0 / 500: loss 2.302783
# iteration 100 / 500: loss 2.302783
# iteration 200 / 500: loss 2.302724
# iteration 300 / 500: loss 2.302676
# iteration 400 / 500: loss 2.302716
# iteration 0 / 500: loss 2.302759
# iteration 100 / 500: loss 2.302746
# iteration 200 / 500: loss 2.302712
# iteration 300 / 500: loss 2.302684
# iteration 400 / 500: loss 2.302620
# iteration 0 / 500: loss 2.302814
# iteration 100 / 500: loss 2.302798
# iteration 200 / 500: loss 2.302755
# iteration 300 / 500: loss 2.302741
# iteration 400 / 500: loss 2.302704
# iteration 0 / 500: loss 2.302843
# iteration 100 / 500: loss 2.302819
# iteration 200 / 500: loss 2.302767
# iteration 300 / 500: loss 2.302747
# iteration 400 / 500: loss 2.302699
# iteration 0 / 500: loss 2.302861
# iteration 100 / 500: loss 2.302806
# iteration 200 / 500: loss 2.302755
# iteration 300 / 500: loss 2.302750
# iteration 400 / 500: loss 2.302732
# iteration 0 / 500: loss 2.302977
# iteration 100 / 500: loss 2.302958
# iteration 200 / 500: loss 2.302848
# iteration 300 / 500: loss 2.302839
# iteration 400 / 500: loss 2.302782
# iteration 0 / 500: loss 2.302984
# iteration 100 / 500: loss 2.302952
# iteration 200 / 500: loss 2.302920
# iteration 300 / 500: loss 2.302884
# iteration 400 / 500: loss 2.302847
# iteration 0 / 500: loss 2.302978
# iteration 100 / 500: loss 2.302925
# iteration 200 / 500: loss 2.302943
# iteration 300 / 500: loss 2.302922
# iteration 400 / 500: loss 2.302876
# iteration 0 / 500: loss 2.303033
# iteration 100 / 500: loss 2.302997
# iteration 200 / 500: loss 2.302926
# iteration 300 / 500: loss 2.302902
# iteration 400 / 500: loss 2.302866
# iteration 0 / 500: loss 2.303065
# iteration 100 / 500: loss 2.303017
# iteration 200 / 500: loss 2.302978
# iteration 300 / 500: loss 2.302974
# iteration 400 / 500: loss 2.302972
# iteration 0 / 500: loss 2.303064
# iteration 100 / 500: loss 2.303049
# iteration 200 / 500: loss 2.303005
# iteration 300 / 500: loss 2.302980
# iteration 400 / 500: loss 2.302963
# iteration 0 / 500: loss 2.303148
# iteration 100 / 500: loss 2.303088
# iteration 200 / 500: loss 2.303066
# iteration 300 / 500: loss 2.303013
# iteration 400 / 500: loss 2.302995
# iteration 0 / 500: loss 2.303334
# iteration 100 / 500: loss 2.303305
# iteration 200 / 500: loss 2.303276
# iteration 300 / 500: loss 2.303236
# iteration 400 / 500: loss 2.303208

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.438

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# *Your answer*:
# 1.3.
# *Your explanation:*
# 1.a larger dataset means less bias toward a particular set of data
# 3.high regularization strengths decreases bias and increases variance
